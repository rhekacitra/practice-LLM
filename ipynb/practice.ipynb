# %% [markdown]
# # ipynb Practice Tasks

# %% [markdown]
# This file contains the practice tasks assigned from LLM Quiz for **Part 2: Familiarity with ipynb files.**
#
# In this file, I will be using Pandas to load a CSV file (`articles.csv`) and plot the graph.
#
# The github link:
# https://github.com/rhekacitra/practice-LLM.git

# %%
# Import pandas and matplotlib
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# ### Load the dataset

# %%
df = pd.read_csv("articles.csv")
df
# Out:
#     id              title       category
# 0    1   Sample Article 1    Programming
# 1    2   Sample Article 2  Entertainment
# 2    3   Sample Article 3         Sports
# 3    4   Sample Article 4         Health
# 4    5   Sample Article 5         Travel
# 5    6   Sample Article 6         Travel
# 6    7   Sample Article 7           Food
# 7    8   Sample Article 8         Sports
# 8    9   Sample Article 9  Entertainment
# 9   10  Sample Article 10     Technology
# 10  11  Sample Article 11            NaN
# 11  12  Sample Article 12  Entertainment
# 12  13  Sample Article 13    Programming
# 13  14  Sample Article 14  Entertainment
# 14  15                NaN  Entertainment
# 15  16                NaN    Programming
# 16  17  Sample Article 17         Sports
# 17  18  Sample Article 18    Programming
# 18  19  Sample Article 19        Finance
# 19  20  Sample Article 20         Health
# 20  21  Sample Article 21         Travel
# 21  22  Sample Article 22    Programming
# ...

# %% [markdown]
# ### Check for missing values

# %%
df.isna().sum()
# Out:
# id          0
# title       3
# category    5
# dtype: int64

# %% [markdown]
# ### Dropping the rows that have missing values and only take columns `title` and `category`

# %%
df.dropna(inplace=True)
df = df[['title', 'category']]
df.head()
# Out:
#               title       category
# 0  Sample Article 1    Programming
# 1  Sample Article 2  Entertainment
# 2  Sample Article 3         Sports
# 3  Sample Article 4         Health
# 4  Sample Article 5         Travel

# %% [markdown]
# ### Plot the category

# %%
category_counts = df['category'].value_counts()
category_counts
# Out:
# category
# Sports           7
# Programming      6
# Travel           6
# Technology       6
# Entertainment    5
# Food             5
# Finance          4
# Health           3
# Education        1
# Name: count, dtype: int64

# %%
# choose barplot
category_counts.plot(kind='bar', figsize=(10,6))

# title
plt.title('Number of Articles per Category')

# x-axis title
plt.xlabel('Category')

# y-axis title
plt.ylabel('Number of Articles')
plt.show()
